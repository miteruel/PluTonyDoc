# %% [markdown]
# Hola p4d.
# This is the very first doc to explain PluTony.

# %% [markdown]
# The first steep is to import the PluTony library,
# also you can import other tipical modules like pandas.

# %%
import HelloPlutony_Dll
import pandas as pd

# %% [markdown]
# PluTony dll has several "submodules" wich may be imported too.
# Now, you can access directory and file objects from plutony

# %%
import PluTony as Ply
# Ply is a shortcut to PluTony

D = Ply.Directory('e:\d2009s')
print (D)
# print (D. root)

for j in D:
        print (j)
OD=D//'elisa'
print (OD)
for j in OD:
        print (j)
        
# D=None
L = Ply.PyXStringList(1, 2,'hola', 3, 4)
print (L)
for i in L:
  print (i, type(i))
# Out:
# (e:\d2009s)
# (e:\d2009s\elisa)
# <Delphi TStrings at D1FCB08>
# 1 <class 'str'>
# 2 <class 'str'>
# hola <class 'str'>
# 3 <class 'str'>
# 4 <class 'str'>

# %% [markdown]
# you can create an CSV text in your appp

# %%
simple = Ply.rtti_rec.Mor.FilesInCSV('*.*')
print (simple)
# Out:
# id,simple,url,sample,info,type
# 0,.gitignore,e:\python\.gitignore,44,time01/04/2022,file
# 1,crypto.ipynb,e:\python\crypto.ipynb,43136,time01/04/2022,file
# 2,holadelphi.ipynb,e:\python\holadelphi.ipynb,72827,time01/04/2022,file
# 3,jupyter - Acceso directo http.lnk,e:\python\jupyter - Acceso directo http.lnk,937,time01/04/2022,file
# 4,jupyter - Acceso directo.lnk,e:\python\jupyter - Acceso directo.lnk,773,time01/04/2022,file
# 5,libzmq.dll,e:\python\libzmq.dll,229888,time01/04/2022,file
# 6,LICENSE.txt,e:\python\LICENSE.txt,32628,time01/04/2022,file
# 7,NEWS.txt,e:\python\NEWS.txt,943426,time01/04/2022,file
# 8,pasca.ipynb,e:\python\pasca.ipynb,4011,time01/04/2022,file
# 9,PDOXUSRS.NET,e:\python\PDOXUSRS.NET,13030,time01/04/2022,file
# 10,PluTonyAdvent_dll.pyd,e:\python\PluTonyAdvent_dll.pyd,5726208,time01/04/2022,file
# 11,PluTony_dll.pyd,e:\python\PluTony_dll.pyd,7275520,time01/04/2022,file
# 12,PluTony_Pandas.ipynb,e:\python\PluTony_Pandas.ipynb,20970,time01/04/2022,file
# 13,python.exe,e:\python\python.exe,98992,time01/04/2022,file
# 14,python3.dll,e:\python\python3.dll,59568,time01/04/2022,file
# 15,python310.dll,e:\python\python310.dll,4471024,time01/04/2022,file
# 16,python38.dll,e:\python\python38.dll,4052656,time01/04/2022,file
# 17,pythonw.exe,e:\python\pythonw.exe,97456,time01/04/2022,file
# 18,p_ython310.dll,e:\python\p_ython310.dll,4471024,time01/04/2022,file
# 19,scriptdll.pyd,e:\python\scriptdll.pyd,10978304,time01/04/2022,file
# 20,testplot.ipynb,e:\python\testplot.ipynb,23899,time01/04/2022,file
# 21,testwebseminar2.ipynb,e:\python\testwebseminar2.ipynb,42178,time01/04/2022,file
# 22,Untitled.ipynb,e:\python\Untitled.ipynb,6368,time01/04/2022,file
# 23,Untitled1.ipynb,e:\python\Untitled1.ipynb,25731,time01/04/2022,file
# 24,Untitled2.ipynb,e:\python\Untitled2.ipynb,2104,time01/04/2022,file
# 25,vcruntime140.dll,e:\python\vcruntime140.dll,76168,time01/04/2022,file
# 26,vcruntime140_1.dll,e:\python\vcruntime140_1.dll,37240,time01/04/2022,file
# 27,zerolib.py,e:\python\zerolib.py,417,time01/04/2022,file
# 28,.ipynb_checkpoints,e:\python\.ipynb_checkpoints,0,time01/04/2022,dir
# 29,archivado,e:\python\archivado,0,time01/04/2022,dir
# 30,Delphi4PythonExporter-main,e:\python\Delphi4PythonExporter-main,0,time01/04/2022,dir
# 31,DelphiVCL4Python-main,e:\python\DelphiVCL4Python-main,0,time01/04/2022,dir
# 32,DelphiZeroMQ-master_ld,e:\python\DelphiZeroMQ-master_ld,0,time01/04/2022,dir
# 33,delphizmq_dep,e:\python\delphizmq_dep,0,time01/04/2022,dir
# 34,DLLs,e:\python\DLLs,0,time01/04/2022,dir
# 35,Doc,e:\python\Doc,0,time01/04/2022,dir
# 36,etc,e:\python\etc,0,time01/04/2022,dir
# 37,full-blockchain-solidity-course-py-main,e:\python\full-blockchain-solidity-course-py-main,0,time01/04/2022,dir
# 38,include,e:\python\include,0,time01/04/2022,dir
# 39,ipykernel-master,e:\python\ipykernel-master,0,time01/04/2022,dir
# 40,IPython,e:\python\IPython,0,time01/04/2022,dir
# 41,jupyter,e:\python\jupyter,0,time01/04/2022,dir
# 42,jupyter_contrib_nbextensions,e:\python\jupyter_contrib_nbextensions,0,time01/04/2022,dir
# 43,lape-master,e:\python\lape-master,0,time01/04/2022,dir
# 44,lazarus,e:\python\lazarus,0,time01/04/2022,dir
# 45,Lib,e:\python\Lib,0,time01/04/2022,dir
# 46,libs,e:\python\libs,0,time01/04/2022,dir
# 47,miteruel,e:\python\miteruel,0,time01/04/2022,dir
# 48,mod_pascal-master,e:\python\mod_pascal-master,0,time01/04/2022,dir
# 49,nba_gateway-master,e:\python\nba_gateway-master,0,time01/04/2022,dir
# 50,NET,e:\python\NET,0,time01/04/2022,dir
# 51,pascalscript-master,e:\python\pascalscript-master,0,time01/04/2022,dir
# 52,PyScripter,e:\python\PyScripter,0,time01/04/2022,dir
# 53,pyscripter-master,e:\python\pyscripter-master,0,time01/04/2022,dir
# 54,python4delphi,e:\python\python4delphi,0,time01/04/2022,dir
# 55,pyzmq-main,e:\python\pyzmq-main,0,time01/04/2022,dir
# 56,sample,e:\python\sample,0,time01/04/2022,dir
# 57,Scripts,e:\python\Scripts,0,time01/04/2022,dir
# 58,share,e:\python\share,0,time01/04/2022,dir
# 59,tcl,e:\python\tcl,0,time01/04/2022,dir
# 60,Tools,e:\python\Tools,0,time01/04/2022,dir
# 61,venv,e:\python\venv,0,time01/04/2022,dir
# 62,zerorpc-python-master,e:\python\zerorpc-python-master,0,time01/04/2022,dir
# 63,zguide-master,e:\python\zguide-master,0,time01/04/2022,dir
# 64,zmq-pykernel-master,e:\python\zmq-pykernel-master,0,time01/04/2022,dir
# 65,__history,e:\python\__history,0,time01/04/2022,dir
# 66,__pycache__,e:\python\__pycache__,0,time01/04/2022,dir

# %% [markdown]
# Now you can convert the csv string to pandas object.

# %%
import io  
test=simple
df=pd.read_csv(io.StringIO(test));
df
# Out:
#     id                             simple  \
# 0    0                         .gitignore
# 1    1                       crypto.ipynb
# 2    2                   holadelphi.ipynb
# 3    3  jupyter - Acceso directo http.lnk
# 4    4       jupyter - Acceso directo.lnk
# ..  ..                                ...
# 62  62              zerorpc-python-master
# 63  63                      zguide-master
# 64  64                zmq-pykernel-master
# 65  65                          __history
# 66  66                        __pycache__
#
#                                             url  sample            info  type
# 0                          e:\python\.gitignore      44  time01/04/2022  file
# 1                        e:\python\crypto.ipynb   43136  time01/04/2022  file
# 2                    e:\python\holadelphi.ipynb   72827  time01/04/2022  file
# 3   e:\python\jupyter - Acceso directo http.lnk     937  time01/04/2022  file
# 4        e:\python\jupyter - Acceso directo.lnk     773  time01/04/2022  file
# ..                                          ...     ...             ...   ...
# 62              e:\python\zerorpc-python-master       0  time01/04/2022   dir
# 63                      e:\python\zguide-master       0  time01/04/2022   dir
# 64                e:\python\zmq-pykernel-master       0  time01/04/2022   dir
# 65                          e:\python\__history       0  time01/04/2022   dir
# 66                        e:\python\__pycache__       0  time01/04/2022   dir
#
# [67 rows x 6 columns]
